# %%
# import requests
# from ntlm import HTTPNtlmAuthHandler
# from requests_ntlm import HttpNtlmAuth, HttpNtlmSspiAuth

# from math import sin, pi
# from bokeh.plotting import line
# from bokeh.resources import CDN
# from bokeh.embed import file_html

# x = range(100)
# y = [sin(2.*pi*(1./25.)*x_) for x_ in x]
# plot = line(x, y, color="red")
# html = file_html(plot, CDN, "Sine")

# %%
import pandas as pd
# import bokeh as bk
import matplotlib as mpl
import datetime
# import bokeh.plotting as bp
import bokeh.layouts
from bokeh.resources import CDN
from bokeh.embed import file_html
from bokeh.layouts import widgetbox, row, layout
from bokeh.models.widgets import Dropdown, DataTable, TableColumn, Toggle, Select


from bokeh.io import output_notebook, push_notebook, show
from bokeh.plotting import figure, show, output_file
from bokeh.models import HoverTool, PanTool, WheelZoomTool, ResetTool, ColumnDataSource, SaveTool, CustomJS

fileName = 'Competency Matrix - JaxAlpha.xlsx'
x1 = pd.ExcelFile(fileName)
x1.sheet_names
# Out:
# ['Matrix', 'Competency Key', 'Lists', 'Competencies']

# %%
df = x1.parse("Matrix")

# movies.Film = movies.Film.astype('category')
# df['ETL']
df.head()
# Out:
#      Name (Last, First)              Level      Location Department  \
# 0           Allan Hoang        Associate I  Jacksonville        FSO
# 1       Bhardwaj,Punica  Associate Analyst  Jacksonville        FSO
# 2  Campos Gembe, Brenda  Associate Analyst  Jacksonville        FSO
# 3        Cardenas, Javi  Associate Analyst  Jacksonville        FSO
# 4       Carter, Anthony  Associate Analyst  Jacksonville        FSO
#
#   Role/function Practice     Last Update Date Ab Initio Adaptive Advanced SQL  \
# 0           SDC      DnA  2017-07-24 00:00:00      Flag        0            1
# 1           SDC      DnA  2017-01-31 00:00:00         0        0            1
# 2           SDC      DnA  2017-02-03 00:00:00         0        0            1
# 3           SDC      DnA  2017-01-31 00:00:00         0        0            2
# 4           SDC      DnA  2017-02-04 00:00:00         0        0         Flag
#
#    ...    SAS Spotfire  SPSS Tableau Teradata Test Director Trillum  Unix  \
# 0  ...   Flag     Flag  Flag       1     Flag             0       0     1
# 1  ...   Flag     Flag     1    Flag        2             0       0   NaN
# 2  ...   Flag     Flag  Flag    Flag     Flag             0       0  Flag
# 3  ...   Flag     Flag     0    Flag     Flag             0       0   NaN
# 4  ...   Flag     Flag     0    Flag        0          Flag       0   NaN
#
#     VBA Visio
# 0     1     1
# 1   NaN   NaN
# 2  flag     1
# 3   NaN   NaN
# 4   NaN   NaN
#
# [5 rows x 48 columns]

# %%
df = df.astype(str)

# %%
df.columns = [c.replace(' ', '').replace('(Last,First)', '') for c in df.columns]
df.head()
# Out:
#                    Name              Level      Location Department  \
# 0           Allan Hoang        Associate I  Jacksonville        FSO
# 1       Bhardwaj,Punica  Associate Analyst  Jacksonville        FSO
# 2  Campos Gembe, Brenda  Associate Analyst  Jacksonville        FSO
# 3        Cardenas, Javi  Associate Analyst  Jacksonville        FSO
# 4       Carter, Anthony  Associate Analyst  Jacksonville        FSO
#
#   Role/function Practice       LastUpdateDate AbInitio Adaptive AdvancedSQL  \
# 0           SDC      DnA  2017-07-24 00:00:00     Flag        0           1
# 1           SDC      DnA  2017-01-31 00:00:00        0        0           1
# 2           SDC      DnA  2017-02-03 00:00:00        0        0           1
# 3           SDC      DnA  2017-01-31 00:00:00        0        0           2
# 4           SDC      DnA  2017-02-04 00:00:00        0        0        Flag
#
#    ...    SAS Spotfire  SPSS Tableau Teradata TestDirector Trillum  Unix  \
# 0  ...   Flag     Flag  Flag       1     Flag            0       0     1
# 1  ...   Flag     Flag     1    Flag        2            0       0   nan
# 2  ...   Flag     Flag  Flag    Flag     Flag            0       0  Flag
# 3  ...   Flag     Flag     0    Flag     Flag            0       0   nan
# 4  ...   Flag     Flag     0    Flag        0         Flag       0   nan
#
#     VBA Visio
# 0     1     1
# 1   nan   nan
# 2  flag     1
# 3   nan   nan
# 4   nan   nan
#
# [5 rows x 48 columns]

# %%
list(df)
# Out:
# ['Name',
#  'Level',
#  'Location',
#  'Department',
#  'Role/function',
#  'Practice',
#  'LastUpdateDate',
#  'AbInitio',
#  'Adaptive',
#  'AdvancedSQL',
#  'ASG',
#  'BluePrism',
#  'Collibra',
#  'DataLineage',
#  'DataTestingPlaybook',
#  'DataFlux',
#  'ETL',
#  'Excel',
#  'Hadoop',
#  'HPQC(HPQualityCenter)',
#  'IBMDataStage',
#  'IBMInfoSpheres',
#  'Informatica',
#  'JAVA',
#  'JAVAScript',
#  'JIRA',
#  'MetadataFactoryPlaybook',
#  'Microstrategy',
#  'Openspan',
#  'Python',
#  'QlikSense',
#  'QlikView',
#  'R',
#  'SAPBusinessObjects(ETL)',
#  'SAPFiori',
#  'SAPHANA',
#  'SAPLumira',
#  'SAPPredictiveAnalysis',
#  'SAS',
#  'Spotfire',
#  'SPSS',
#  'Tableau',
#  'Teradata',
#  'TestDirector',
#  'Trillum',
#  'Unix',
#  'VBA',
#  'Visio']

# %%
now = datetime.datetime.now()
curDate = datetime.datetime.date(datetime.datetime.now())
# output_file('matrix'+ str(curDate) +'.html', title="Competency Matrix")
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="36b005ec-20bf-4716-abeb-25cfa44a5d0a">Loading BokehJS ...</span>
#     </div>

# %%
myData = {}
columnName = 'AbInitio'
myData [columnName] = columnName
# df.loc[(df.columnName) == 'Flag', columnName] = -1
# df.loc[(df[columnName]) == 'Flag', columnName] = -1
# df

# %%
df2 = df[df.Location =="Alpharetta"]
# df2

# %%
df1 = df[df.Location =='Jacksonville']
# df1

# %%
source = ColumnDataSource(data = dict(x=df['ETL'], y =df['Name'], Location =df['Location']))
mySource =ColumnDataSource(df.to_dict(orient='list'))
mySource1 = ColumnDataSource(df1.to_dict(orient='list'))
source1 = ColumnDataSource(data = dict(x=df1['ETL'], y =df1['Name'], Location =df1['Location']))
mySource2 = ColumnDataSource(df2.to_dict(orient='list'))
source2 = ColumnDataSource(data = dict(x=df2['ETL'], y =df2['Name'], Location =df2['Location']))
print(source)
# Out:
# ColumnDataSource(id='53b22ad7-fc3c-4cde-86bc-8c6470a428bf', ...)

# %%
Names = df['Name'].values.tolist()

# %%
#Scatter Plot

xrange = ['Flag', '0', '1' ,'2', '3', '4']
p = figure(title = "Competency", x_range = xrange, y_range = Names, tools = "pan, wheel_zoom, reset", 
           x_axis_label = "Skill Level", y_axis_label = "Names", output_backend = 'canvas')
figure.sizing_mode = 'scale_both'

#Output backend is in the latest bokeh/allows IE use. Need to update if throwing an error
#Comment out for now
# p = figure(output_backend = 'canvas')
# circles = p.circle(x = 'x',y = 'y', source = source, color = 'red', muted_color = 'lightgrey',fill_alpha=0.2, size=10)
p.circle(x ='x',y = "y", source = source1, color = 'red', muted_color = 'lightgrey',fill_alpha=0.2, size=10, legend = 'Jacksonville')
p.circle(x ='x' ,y = "y", source = source2, color = 'blue', muted_color ='lightgrey', fill_alpha=0.2, size=10, legend = 'Alpharetta')
p.legend.location = "top_right"
p.legend.click_policy="mute"
# p = Scatter(source =mySource1, y='Name',x='ETL',marker='square')

p.add_tools (HoverTool(tooltips=[
    ("Name", "$y"),
    ("Skill Level", "$x{int}"),
    ("Location", "@Location")
]))
# row()
# show(widgetbox(dropdown))
# p.add_tools("pan, wheel_zoom, reset")

# %%
columns = [
        TableColumn(field="y", title="Name"),
        TableColumn(field='x', title="Skill"),
        #Need to add callback and interactiveness to DT
        TableColumn(field="Location", title ="Location")
    ]
data_table = DataTable(source=source, columns=columns, width=400, height=500)

# %%
# menu = df.columns.tolist()

menu =[]
for i, column in enumerate(df, start =0):
    if i >=7:
        item = (column)
        menu.append(item)

#dropdown button
# from bokeh.models.widgets import Dropdown
# from bokeh.io import output_file, show, vform

output_file('matrix'+ str(curDate) +'.html', title = "Competency Matrix")

# menu = [("Item 1", "item_1"), ("Item 2", "item_2"), None, ("Item 3", "item_3")]

# callback = CustomJS(args={'source':source, 'mySource':mySource, 'data_table':data_table}, code="""
#     var data = source.data;
#     var data2 = mySource.data;
#     var f =skill.value;
#     x = data2[f];
#     data['x'] = x;
#     source.trigger('change');
#     data_table.trigger('change');
# """)
callback = CustomJS(args={'source1':source1, 'source2':source2, 'mySource1':mySource1, 'mySource2':mySource,
                          'source':source,'mySource':mySource ,'data_table':data_table}, code="""
    var data = source1.data;
    var data1 = mySource1.data;
    var data2 = source2.data;
    var data3 = mySource2.data;
    var dt_data = source.data;
    var dt_data1 = mySource.data;
    var f =skill.value;
    x1 = data1[f];
    x2 = data3[f];
    dt_x = dt_data1[f];
    data['x'] = x1;
    data2['x'] = x2;
    dt_data['x'] = dt_x;
    
    source.trigger('change');
    source1.trigger('change');
    source2.trigger('change');
    data_table.trigger('change');
""")                          

# var f = cb_obj.value;
# source.change.emit();
# source.trigger('change');
select = Select(title="Select", value = columnName, options=menu, callback = callback)
callback.args["skill"] = select

# select.js_on_change('value', callback)
# callback.args["category"] = dropdown

# %%
# # To filter out by engagement status soon
# buttonCode='''
# object.visible = toggle.active
# ''')

# callback1 =CustomJS.from_coffeescript(code=buttonCode,args('toggle':toggle1, 'object'))

# toggle1 = Toggle(label="Engagement", button_type="success", callback=callback1,
#  active=True)
# toggle2 = Toggle(label="Wants to Switch", button_type="success", callback=callback1,
#  active=True)
# toggle3 = Toggle(label="On Bench", button_type="success", callback=callback1,
#  active=True)

# %%
layout = row(p, (widgetbox(select, data_table)))
show(layout)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f2fe5c7f-0222-44f9-8854-aa6526c08c76"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f2fe5c7f-0222-44f9-8854-aa6526c08c76");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f2fe5c7f-0222-44f9-8854-aa6526c08c76");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f2fe5c7f-0222-44f9-8854-aa6526c08c76' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b6d094ca-0e8a-44dd-834a-13227da34a48":{"roots":{"references":[{"attributes":{"fill_color":{"value":"lightgrey"},"line_color":{"value":"lightgrey"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"d5e4b337-c6ec-4602-916e-31d257cd0249","type":"Circle"},{"attributes":{},"id":"a46053ef-0389-44b1-87fe-e874e5e08e77","type":"StringEditor"},{"attributes":{"callback":null,"column_names":["Name","Level","Location","Department","Role/function","Practice","LastUpdateDate","AbInitio","Adaptive","AdvancedSQL","ASG","BluePrism","Collibra","DataLineage","DataTestingPlaybook","DataFlux","ETL","Excel","Hadoop","HPQC(HPQualityCenter)","IBMDataStage","IBMInfoSpheres","Informatica","JAVA","JAVASc