# %%
import pandas as pd

# %%
#Method 1: Full path
#Windows
stats = pd.read_csv('C:\\Users\\db375qf\\Desktop\\Jupyter Notebooks\\Python Programming Course\\Datasets\\DemographicData.csv')

# %%
stats
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
#Method 2: Change Directory
import os
print(os.getcwd())
# Out:
# C:\Users\db375qf\Desktop\Jupyter Notebooks\Python Programming Course

# %%
os.chdir('C:\\Users\\db375qf\\Desktop\\Jupyter Notebooks\\Python Programming Course\\Datasets')
print(os.getcwd())
# Out:
# C:\Users\db375qf\Desktop\Jupyter Notebooks\Python Programming Course\Datasets

# %%
stats2 = pd.read_csv('DemographicData.csv')

# %%
stats2
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
#Exploring data

# %%
#2. Number of Rows
len(stats)
# Out:
# 195

# %%
# See Columns
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
#Count num of columns
len(stats.columns)
# Out:
# 5

# %%
#top rows
stats.head() #remember brackets
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.head(6)
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
# 5             Argentina          ARG      17.716            59.9
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income

# %%
#Bottom row
stats.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
# info on columns
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
# stats on columns
stats.describe() #Similar to Summary in R
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
stats.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
stats.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
stats.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',\
       'IncomeGroup']

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
###Subsetting dataframes in Pandas
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
#Three parts
#-Rows
#-Columns
#-Combine the two

#Rows
stats[21:26]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 21      Belize         BLZ     23.092          33.60  Upper middle income
# 22     Bermuda         BMU     10.400          95.30          High income
# 23     Bolivia         BOL     24.236          36.94  Lower middle income
# 24      Brazil         BRA     14.931          51.04  Upper middle income
# 25    Barbados         BRB     12.188          73.00          High income

# %%
stats[::-1]
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 194                        Zimbabwe         ZWE     35.715       18.50000
# 193                          Zambia         ZMB     40.471       15.40000
# 192                Congo, Dem. Rep.         COD     42.394        2.20000
# 191                    South Africa         ZAF     20.850       46.50000
# 190                     Yemen, Rep.         YEM     32.947       20.00000
# 189                           Samoa         WSM     26.172       15.30000
# 188              West Bank and Gaza         PSE     30.394       46.60000
# 187                         Vanuatu         VUT     26.739       11.30000
# 186                         Vietnam         VNM     15.537       43.90000
# 185           Virgin Islands (U.S.)         VIR     10.700       45.30000
# 184                   Venezuela, RB         VEN     19.842       54.90000
# 183  St. Vincent and the Grenadines         VCT     16.306       52.00000
# ...

# %%
stats['CountryName']
# Out:
# 0                               Aruba
# 1                         Afghanistan
# 2                              Angola
# 3                             Albania
# 4                United Arab Emirates
# 5                           Argentina
# 6                             Armenia
# 7                 Antigua and Barbuda
# 8                           Australia
# 9                             Austria
# 10                         Azerbaijan
# 11                            Burundi
# 12                            Belgium
# 13                              Benin
# 14                       Burkina Faso
# 15                         Bangladesh
# 16                           Bulgaria
# 17                            Bahrain
# 18                       Bahamas, The
# 19             Bosnia and Herzegovina
# 20                            Belarus
# 21                             Belize
# 22                            Bermuda
# 23                            Bolivia
# 24                             Brazil
# ...

# %%
stats['CountryName'].head()
# Out:
# 0                   Aruba
# 1             Afghanistan
# 2                  Angola
# 3                 Albania
# 4    United Arab Emirates
# Name: CountryName, dtype: object

# %%
stats[['CountryName', 'BirthRate']].head()
# Out:
#             CountryName  BirthRate
# 0                 Aruba     10.244
# 1           Afghanistan     35.253
# 2                Angola     45.985
# 3               Albania     12.877
# 4  United Arab Emirates     11.044

# %%
# In R you would be passing a vector
stats[['BirthRate', 'CountryName']].head()
# Out:
#    BirthRate           CountryName
# 0     10.244                 Aruba
# 1     35.253           Afghanistan
# 2     45.985                Angola
# 3     12.877               Albania
# 4     11.044  United Arab Emirates

# %%
#Quick Access
stats.BirthRate.head()
# Out:
# 0    10.244
# 1    35.253
# 2    45.985
# 3    12.877
# 4    11.044
# Name: BirthRate, dtype: float64

# %%
#Part 3 Combining the two
df2 = stats[4:8][['CountryName', 'BirthRate']]
df2
# Out:
#             CountryName  BirthRate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %%
stats[['CountryName', 'BirthRate']][4:8]
# Out:
#             CountryName  BirthRate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %%
df1 = stats[['CountryName', 'BirthRate']]
df1[4:8]
# Out:
#             CountryName  BirthRate
# 4  United Arab Emirates     11.044
# 5             Argentina     17.716
# 6               Armenia     13.308
# 7   Antigua and Barbuda     16.447

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[['CountryCode', 'BirthRate', 'InternetUsers']][4:8]
# Out:
#   CountryCode  BirthRate  InternetUsers
# 4         ARE     11.044           88.0
# 5         ARG     17.716           59.9
# 6         ARM     13.308           41.9
# 7         ATG     16.447           63.4

# %%
# MAthematical Operation
result = stats.BirthRate  * stats.InternetUsers

# %%
result.head()
# Out:
# 0    808.2516
# 1    207.9927
# 2    878.3135
# 3    736.5644
# 4    971.8720
# dtype: float64

# %%
stats['MyCalc'] = stats.BirthRate * stats.InternetUsers

# %%
#stats.drop('myCalc', 1)

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup    MyCalc
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
#Comparison to R
stats['xyz'] = [1,2,3,4,5] #No recycling option
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-829fb2f9985a> in <module>()
#       1 #Comparison to R
# ----> 2 stats['xyz'] = [1,2,3,4,5] #No recycling option
#
# C:\Users\db375qf\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2427         else:
#    2428             # set column
# -> 2429             self._set_item(key, value)
#    2430
#    2431     def _setitem_slice(self, key, value):
#
# C:\Users\db375qf\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2493
#    2494         self._ensure_valid_index(value)
# -> 2495         value = self._sanitize_column(key, value)
#    2496         NDFrame._set_item(self, key, value)
#    2497
#
# ...

# %%
# must declare datframe = to save the dataframe
stats = stats.drop('myCalc', 1)
stats.head()

# %%
###Filtering Data Frames
#Filtering is about Rows

# %%
stats.InternetUsers < 2

# %%
Filter = (stats.InternetUsers < 2)

# %%
Filter

# %%
stats[Filter]

# %%
Filter2 = stats.BirthRate > 40

# %%
stats[Filter2]

# %%
stats[stats.BirthRate > 40 and stats.InternetUsers < 2]

# %%
Filter and Filter2

# %%
#Need brackets and parenthesis to signify what to process first
stats[(stats.BirthRate > 40) & (stats.InternetUsers < 2)]

# %%
stats[stats.IncomeGroup == "High income"]

# %%
#Getting unique categories
stats.IncomeGroup.unique()

# %%
#Finding things about Malta
stats[stats.CountryName == "Malta"]

# %%
###Accessing individual elements
stats[2,2] #Error. Why?!

# %%
stats.head()

# %%
#.at #for labels. Important: even integers are treated as lavels
#.iat #for interger location

# %%
stats.iat[3,4]

# %%
stats.iat[0,1]

# %%
stats.iat[0,1]

# %%
stats.at[2, 'BirthRate']
# Out:
# 45.984999999999999

# %%
sub10 = stats[::10]
sub10

# %%
stats.iat[10,0]

# %%
sub10.iat[10, 0]

# %%
sub10.at[10, 'CountryName']

# %%
#Introduction to Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = 8 , 4
import warnings

# %%
stats.head()

# %%
#Distribution
vis1 = sns.distplot(stats["InternetUsers"], )

# %%
vis1 = sns.distplot(stats["InternetUsers"], bins = 30 )

# %%
vis1 = sns.distplot(stats["InternetUsers"], bins = 100)

# %%
#Boxplots:
vis2 = sns.boxplot(data = stats, x="IncomeGroup", y = "BirthRate")

# %%
vis2 = sns.barplot(data = stats, x ="IncomeGroup", y = "BirthRate")

# %%
vis3 = sns.lmplot(data = stats, x='InternetUsers', y = 'BirthRate')

# %%
vis3 = sns.lmplot(data = stats, x='InternetUsers', y = 'BirthRate', \
                  fit_reg=False, hue = 'IncomeGroup', size = 10, aspect=2 )

# %%
vis4 = sns.distplot(stats["BirthRate"], bins=30)

# %%
vis3 = sns.lmplot(data = stats, x='InternetUsers', y = 'BirthRate', \
                  fit_reg=False, hue = 'IncomeGroup', size = 10, \
                 scatter_kws={"s":200})

# %%
###Keyword Arguments in Python (advanced)
